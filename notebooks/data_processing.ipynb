# %%
# Indian food soooo yummmy

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('../data/indian_food.csv')
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# 0    vegetarian         45         25          sweet  dessert
# 1    vegetarian         80         30          sweet  dessert
# 2    vegetarian         15         60          sweet  dessert
# 3    vegetarian         15         30          sweet  dessert
# 4    vegetarian         15         40          sweet  dessert
# ..          ...        ...        ...            ...      ...
# 250  vegetarian          5         30          sweet  dessert
# 251  vegetarian         20         60          sweet  dessert
# 252  vegetarian         -1         -1          sweet  dessert
# 253  vegetarian         20         45          sweet  dessert
# 254  vegetarian         -1         -1          sweet  dessert
#
#                state      region
# 0        West Bengal        East
# 1          Rajasthan        West
# 2             Punjab       North
# 3          Rajasthan        West
# 4        West Bengal        East
# ..               ...         ...
# 250            Assam  North East
# 251              Goa        West
# 252  Jammu & Kashmir       North
# 253   Madhya Pradesh     Central
# 254              Goa        West
#
# [255 rows x 9 columns]

# %%
df['cook_time'][df['cook_time'] < 1].count(), df['prep_time'][df['prep_time'] < 1].count()
# Out:
# (28, 30)

# %%
df[['state', 'region', 'flavor_profile', 'course', 'diet']].value_counts()
# Out:
# state         region      flavor_profile  course       diet
# Punjab        North       spicy           main course  vegetarian        21
# Gujarat       West        spicy           snack        vegetarian        15
# West Bengal   East        sweet           dessert      vegetarian        15
# Maharashtra   West        sweet           dessert      vegetarian        12
# Tamil Nadu    South       spicy           main course  vegetarian        12
#                                                                          ..
# Maharashtra   West        -1              snack        vegetarian         1
# Manipur       North East  -1              main course  non vegetarian     1
#                           sweet           dessert      vegetarian         1
# NCT of Delhi  North       spicy           main course  non vegetarian     1
# West Bengal   East        sweet           main course  vegetarian         1
# Name: count, Length: 83, dtype: int64

# %%
df[df['flavor_profile'] == '-1']
# Out:
#                name                                        ingredients  \
# 78          Chapati  whole wheat flour, olive oil, hot water, all p...
# 104            Naan           whole wheat flour, honey, butter, garlic
# 116           Rongi  garam masala powder, tomato, kasuri methi, cin...
# 131           Kanji     carrot, yellow mustard, red chilli, black salt
# 145         Pachadi  coconut oil, cucumber, curd, curry leaves, mus...
# 146       Paniyaram  yogurt, ginger, curry leaves, baking soda, gre...
# 150   Paruppu sadam  arhar dal, sambar powder, tomato, curry leaves...
# 153      Puli sadam  urad dal, lemon, tamarind, cooked rice, curry ...
# 155           Puttu            brown rice flour, sugar, grated coconut
# 157         Sandige  thin rice flakes, black sesame seeds, curry le...
# 158           Sevai                     sevai, parboiled rice, steamer
# 159    Thayir sadam  urad dal, curd, sesame oil, ginger, curry leav...
# 160         Theeyal  coconut, whole red beans, masala, sesame oil, ...
# 171          Bhakri                          jowar flour, sesame seeds
# 176      Copra paak  condensed milk, nestle cream, coconut ice, red...
# 179       Dahi vada  urad dal, bhuna chana, garam masala, dates, ta...
# 180        Dalithoy  arhar dal, coconut oil, curry leaves, mustard ...
# 189          Kansar                 wheat flour, cashews, rapeseed oil
# 216      Farsi Puri  semolina, clarified butter, oil, white flour, ...
# 222            Khar  raw papaya, panch phoran masala, nigella seeds...
# 224           Luchi                               maida, vegetable oil
# 227  Bengena Pitika     brinjal, onions, salt, sesame seeds, coriander
# 228     Bilahi Maas  potatoes, garam masala, tomatoes, mustard oil,...
# 229      Black rice  forbidden black rice, chicken, olive oil, sliv...
# 231      Brown Rice                   brown rice, soy sauce, olive oil
# 236   Chingri Bhape   coconut, prawns, curd, mustard seed, green chili
# 244         Pakhala        curd, cooked rice, curry leaves, dry chilli
# 245      Pani Pitha  tea leaves, white sesame seeds, dry coconut, s...
# 248        Red Rice  red pepper, red onion, butter, watercress, oli...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 78       vegetarian         10         10             -1  main course
# 104      vegetarian         60         30             -1  main course
# 116      vegetarian         10         30             -1  main course
# 131      vegetarian         10         45             -1        snack
# 145      vegetarian         10         25             -1  main course
# 146      vegetarian         10         20             -1  main course
# 150      vegetarian         10         20             -1  main course
# 153      vegetarian         10         20             -1  main course
# 155      vegetarian        495         40             -1  main course
# 157      vegetarian        120         60             -1  main course
# 158      vegetarian        120         30             -1  main course
# 159      vegetarian         10         20             -1  main course
# 160      vegetarian         15         20             -1  main course
# 171      vegetarian         20         25             -1  main course
# 176      vegetarian         20         30             -1  main course
# 179      vegetarian         30         30             -1        snack
# 180      vegetarian          5         20             -1  main course
# 189      vegetarian         10         40             -1  main course
# 216      vegetarian         -1         -1             -1        snack
# 222      vegetarian         10         20             -1  main course
# 224      vegetarian         20         30             -1  main course
# 227      vegetarian         -1         -1             -1  main course
# 228  non vegetarian         10         20             -1  main course
# 229  non vegetarian         -1         -1             -1  main course
# 231      vegetarian         15         25             -1  main course
# 236  non vegetarian         15         30             -1  main course
# 244      vegetarian         -1         -1             -1  main course
# 245      vegetarian         10         20             -1  main course
# 248      vegetarian         -1         -1             -1  main course
#
#            state      region
# 78   Maharashtra        West
# 104       Punjab       North
# 116       Punjab       North
# 131       Kerala       South
# 145           -1       South
# 146   Tamil Nadu       South
# 150   Tamil Nadu       South
# 153   Tamil Nadu       South
# 155       Kerala       South
# 157    Karnataka       South
# 158           -1       South
# 159   Tamil Nadu       South
# 160       Kerala       South
# 171  Maharashtra        West
# 176      Gujarat        West
# 179  Maharashtra        West
# 180  Maharashtra        West
# 189      Gujarat        West
# 216      Gujarat        West
# 222        Assam  North East
# 224  West Bengal        East
# 227        Assam  North East
# 228        Assam  North East
# 229      Manipur  North East
# 231           -1          -1
# 236  West Bengal        East
# 244       Odisha        East
# 245        Assam  North East
# 248           -1          -1

# %%
df['cook_time'].describe(), df['prep_time'].describe()
# Out:
# (count    255.000000
#  mean      34.529412
#  std       48.265650
#  min       -1.000000
#  25%       20.000000
#  50%       30.000000
#  75%       40.000000
#  max      720.000000
#  Name: cook_time, dtype: float64,
#  count    255.000000
#  mean      31.105882
#  std       72.554409
#  min       -1.000000
#  25%       10.000000
#  50%       10.000000
#  75%       20.000000
#  max      500.000000
#  Name: prep_time, dtype: float64)

# %%
df['ingredients'] = df['ingredients'].map(lambda x: x.lower())
df['ingredients']
# Out:
# 0                        maida flour, yogurt, oil, sugar
# 1                                gram flour, ghee, sugar
# 2           carrots, milk, sugar, ghee, cashews, raisins
# 3      flour, ghee, kewra, milk, clarified butter, su...
# 4      milk powder, plain flour, baking powder, ghee,...
#                              ...
# 250              glutinous rice, black sesame seeds, gur
# 251    coconut milk, egg yolks, clarified butter, all...
# 252    cottage cheese, dry dates, dried rose petals, ...
# 253    milk powder, dry fruits, arrowroot powder, all...
# 254    brown rice, fennel seeds, grated coconut, blac...
# Name: ingredients, Length: 255, dtype: object

# %%
all_ingredients = []
for item in df['ingredients'].tolist():
    [all_ingredients.append(i) for i in item.split(', ') if i not in all_ingredients]
all_ingredients, len(all_ingredients)
# Out:
# (['maida flour',
#   'yogurt',
#   'oil',
#   'sugar',
#   'gram flour',
#   'ghee',
#   'carrots',
#   'milk',
#   'cashews',
#   'raisins',
#   'flour',
#   'kewra',
#   'clarified butter',
#   'almonds',
#   'pistachio',
#   'saffron',
#   'green cardamom',
#   'milk powder',
#   'plain flour',
#   'baking powder',
#   'water',
#   'rose water',
#   'sugar syrup',
#   'lentil flour',
#   'maida',
#   'corn flour',
#   'baking soda',
#   'vinegar',
#   'curd',
#   'turmeric',
#   'cardamom',
#   'cottage cheese',
#   'rice',
#   'dried fruits',
#   'nuts',
#   'refined flour',
#   'besan',
#   'powdered sugar',
#   'yoghurt',
#   'firm white pumpkin',
#   'kitchen lime',
#   'alum powder',
#   'condensed milk',
#   'spices',
#   'semolina',
#   'khoa',
#   'coconut',
#   'molu leaf',
#   'dry fruits',
#   'chhena',
#   'chenna cheese',
#   'cream',
#   'lemon juice',
#   'coconut flakes',
#   'chenna',
#   'fried milk power',
#   'fennel seeds',
#   'besan flour',
#   'jaggery',
#   'rice flour',
#   'wheat flour',
#   'sweetened milk',
#   'reduced milk',
#   'vegetable oil',
#   'elachi',
#   'cardamom powder',
#   'cashews and raisins',
#   'jaggery syrup',
#   'peanuts',
#   'dharwadi buffalo milk',
#   'loaf bread',
#   'salt',
#   'black lentils',
#   'mung bean',
#   'skimmed milk powder',
#   'chickpeas',
#   'chana dal',
#   'apricots',
#   'vermicelli pudding',
#   'banana',
#   'khus-khus seeds',
#   'cucumber',
#   'rava',
#   'jaggery ',
#   'fish',
#   'potol',
#   'tomato',
#   'chillies',
#   'ginger',
#   'garlic',
#   'boiled pork',
#   'onions',
#   'ginger and garlic',
#   'axone',
#   'pork',
#   'cauliflower',
#   'potato',
#   'garam masala',
#   'curry leaves',
#   'bread crumbs',
#   'peas',
#   'fenugreek leaves',
#   'shimla mirch',
#   'amchur powder',
#   'chole',
#   'ladies finger',
#   'kasuri methi',
#   'tomatoes',
#   'chili powder',
#   'chicken thighs',
#   'basmati rice',
#   'star anise',
#   'sweet',
#   'green chillies',
#   'chicken',
#   'greek yogurt',
#   'garam masala powder',
#   'cashew nuts',
#   'butter',
#   'tomato paste',
#   'red onion',
#   'avocado oil',
#   'whole wheat flour',
#   'olive oil',
#   'hot water',
#   'all purpose flour',
#   'dahi',
#   'sesame seeds',
#   'naan bread',
#   'tomato sauce',
#   'skinless chicken breasts',
#   'heavy cream',
#   'whole wheat bread',
#   'whole egg',
#   'bhatura',
#   'bay leaf',
#   'cinnamon stick',
#   'moong dal',
#   'masoor dal',
#   'almond',
#   'green chilli',
#   'red kidney beans',
#   'urad dal',
#   'pigeon peas',
#   'baby potatoes',
#   'beaten rice flakes',
#   'green chilies',
#   'arhar dal',
#   'white urad dal',
#   'dough',
#   'bell peppers',
#   'gravy',
#   'bitter gourd',
#   'fennel',
#   'green peas',
#   'green chili',
#   'paneer',
#   'rose syrup',
#   'falooda sev',
#   'mixed nuts',
#   'bottle gourd',
#   'coconut oil',
#   'roasted gram flour',
#   'nigella seeds',
#   'chilli',
#   'palak',
#   'makki atta',
#   'mustard green',
#   'chickpea flour',
#   'mushroom',
#   'malai',
#   'capsicum',
#   'canned coconut milk',
#   'frozen green peas',
#   'wild mushrooms',
#   'honey',
#   'green beans',
#   'potatoes',
#   'khus khus',
#   'low fat',
#   'whipping cream',
#   'tandoori masala',
#   'bell pepper',
#   'kala chana',
#   'mashed potato',
#   'boondi',
#   'sev',
#   'lemon',
#   'musk melon seeds',
#   'poppy seeds',
#   'edible gum',
#   'chopped tomatoes',
#   'coriander',
#   'arbi ke patte',
#   'gur',
#   'bengal gram flour',
#   'imli',
#   'tea bags',
#   'cinnamon',
#   'mustard oil',
#   'sattu',
#   'atta',
#   'filling',
#   'white bread slices',
#   'baby corn',
#   'french beans',
#   'carrot',
#   'marinade',
#   'biryani masala powder',
#   'fish fillets',
#   'green bell pepper',
#   'kala jeera',
#   'raw banana',
#   'elephant foot yam',
#   'long beans',
#   'tindora',
#   'split pigeon peas',
#   'fresh coconut',
#   'whole urad dal',
#   'blend rice',
#   'rock salt',
#   'grated coconut',
#   'split urad dal',
#   'idli rice',
#   'thick poha',
#   'yellow mustard',
#   'red chilli',
#   'black salt',
#   'sesame oil',
#   'drumstick',
#   'tamarind paste',
#   'sambar powder',
#   'spinach',
#   'mustard seeds',
#   'greens',
#   'fenugreek seeds',
#   'amaranth leaves',
#   'red chili',
#   'beef',
#   'beans',
#   'cabbage',
#   'tamarind',
#   'gooseberry',
#   'raw rice',
#   'pearl onions',
#   'drumsticks',
#   'lentils',
#   'black pepper',
#   ' jaggery',
#   'green moong beans',
#   'mustard',
#   'cooked rice',
#   'brown rice flour',
#   'eggplant',
#   'thin rice flakes',
#   'black sesame seeds',
#   'sevai',
#   'parboiled rice',
#   'steamer',
#   'whole red beans',
#   'masala',
#   'meat curry powder',
#   'chicken chunks',
#   'kala masala',
#   'baingan',
#   'sooji',
#   'pearl millet flour',
#   'mawa',
#   'desiccated coconut',
#   'jowar flour',
#   'bombay duck',
#   'malvani masala',
#   'bombay rava',
#   'sesame',
#   'citric acid',
#   'fry',
#   'chana daal',
#   'dried mango',
#   'nestle cream',
#   'coconut ice',
#   'red food coloring',
#   'dal',
#   'kokum',
#   'pav',
#   'aloo',
#   'peanut',
#   'pomegranate',
#   'bhuna chana',
#   'dates',
#   'green',
#   'sauce',
#   'sliced almonds',
#   'toor dal',
#   'whole wheat rava',
#   'chia seed',
#   'litre milk',
#   'boiled potatoes',
#   'rapeseed oil',
#   'mango',
#   'green chili paste',
#   'white sesame seeds',
#   'dry roasted',
#   'cilantro',
#   'badam',
#   'pav bhaji masala',
#   'gobi',
#   'dinner rolls',
#   'raw peanuts',
#   'sabudana',
#   'khaman',
#   'sunflower oil',
#   'rice flakes',
#   'sorghum flour',
#   'sweet potato',
#   'surti papdi',
#   'valor papdi',
#   'wine vinegar',
#   'green garlic chutney',
#   'fresh green peas',
#   'moong beans',
#   'red chillies',
#   'peanut oil',
#   'methi leaves',
#   'white flour',
#   'ridge gourd',
#   'dry coconut',
#   'sticky rice',
#   'orange rind',
#   'raw papaya',
#   'panch phoran masala',
#   'eggs',
#   'beetroot',
#   'brinjal',
#   'forbidden black rice',
#   'slivered almonds',
#   'garlic powder',
#   'biryani masala',
#   'mixed vegetables',
#   'yellow moong daal',
#   'whole red',
#   'brown rice',
#   'soy sauce',
#   'coconut milk',
#   'lobster',
#   'fresh green chilli',
#   'lamb',
#   'prawns',
#   'mustard seed',
#   'fish fillet',
#   'mint',
#   'fermented bamboo shoot',
#   'banana flower',
#   'mutton',
#   'fish roe',
#   'pumpkin flowers',
#   'dry chilli',
#   'tea leaves',
#   'soaked rice',
#   'cardamom pods',
#   'red pepper',
#   'watercress',
#   'glutinous rice',
#   'egg yolks',
#   'dry dates',
#   'dried rose petals',
#   'arrowroot powder',
#   'ginger powder'],
#  367)
