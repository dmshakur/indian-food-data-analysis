# %%
# Indian food soooo yummmy

# Importing visualization and data handling libraries

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

pd.set_option('display.max.rows', 100)
pd.set_option('display.max_colwidth', 100)

# %% [markdown]
# First things first, always take a quick look at the data so I can have a better idea of what I am working with.
# And going from there I will decide what needs to be changed before I proceed on with the data analysis portion.

# %%
df = pd.read_csv('../data/indian_food.csv')
df.sample(15)
# Out:
#                     name  \
# 114          Pindi chana
# 147              Papadum
# 55                Anarsa
# 103       Mushroom matar
# 234           Hando Guri
# 76        Butter chicken
# 211             Vindaloo
# 193          Kombdi vade
# 22           Chhena poda
# 232  Chingri malai curry
# 12             Nankhatai
# 150        Paruppu sadam
# 140            Koshambri
# 191              Khakhra
# 148           Paravannam
#
#                                                                         ingredients  \
# 114                                Fennel, tea bags, tomato, kasuri methi, cinnamon
# 147                                            Lentils, black pepper, vegetable oil
# 55                                             Rice flour, jaggery, khus-khus seeds
# 103  Canned coconut milk, frozen green peas, wild mushrooms, garam masala, tomatoes
# 234                                                                Jaggery, raisins
# 76           Chicken, greek yogurt, cream, garam masala powder, cashew nuts, butter
# 211                     Chicken, coconut oil, wine vinegar, ginger, green, cinnamon
# 193                         Rice flour, urad dal, wheat flour, gram flour, turmeric
# 22                                                             Sugar, chenna cheese
# 232                    Coconut milk, lobster, fresh green chilli, ginger, red onion
# 12              Refined flour, besan, ghee, powdered sugar, yoghurt, green cardamom
# 150                    Arhar dal, sambar powder, tomato, curry leaves, fennel seeds
# 140                     Moong dal, cucumber, curry leaves, green chili, lemon juice
# 191                                   Whole wheat flour, low fat, bengal gram flour
# 148                                                        Raw rice,  jaggery, milk
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 114      vegetarian        500        120          spicy  main course
# 147      vegetarian          5          5          spicy        snack
# 55       vegetarian         10         50          sweet      dessert
# 103      vegetarian         10         30          spicy  main course
# 234      vegetarian         -1         -1          sweet      dessert
# 76   non vegetarian         10         35          spicy  main course
# 211  non vegetarian         10         40          spicy  main course
# 193      vegetarian         10         25          spicy        snack
# 22       vegetarian         10         45          sweet      dessert
# 232  non vegetarian         10         40          spicy  main course
# 12       vegetarian         20         30          sweet      dessert
# 150      vegetarian         10         20             -1  main course
# 140      vegetarian         10         20          spicy  main course
# 191      vegetarian         20         40          spicy        snack
# 148      vegetarian         -1         -1          spicy  main course
#
#             state      region
# 114        Punjab       North
# 147        Kerala       South
# 55    Maharashtra        West
# 103        Punjab       North
# 234         Assam  North East
# 76   NCT of Delhi       North
# 211           Goa        West
# 193   Maharashtra        West
# 22         Odisha        East
# 232   West Bengal        East
# 12             -1          -1
# 150    Tamil Nadu       South
# 140     Karnataka       South
# 191       Gujarat        West
# 148        Kerala       South

# %% [markdown]
# Before going further I want to make all of the data lower case.

# %%
lower_columns = ['ingredients', 'name', 'state', 'region']
df[lower_columns] = df[lower_columns].map(lambda x: str(x).lower())
df[lower_columns]
# Out:
#                                                                                         ingredients  \
# 0                                                                   maida flour, yogurt, oil, sugar
# 1                                                                           gram flour, ghee, sugar
# 2                                                      carrots, milk, sugar, ghee, cashews, raisins
# 3    flour, ghee, kewra, milk, clarified butter, sugar, almonds, pistachio, saffron, green cardamom
# 4                     milk powder, plain flour, baking powder, ghee, milk, sugar, water, rose water
# ..                                                                                              ...
# 250                                                         glutinous rice, black sesame seeds, gur
# 251                                    coconut milk, egg yolks, clarified butter, all purpose flour
# 252                                  cottage cheese, dry dates, dried rose petals, pistachio, badam
# 253                                    milk powder, dry fruits, arrowroot powder, all purpose flour
# 254                           brown rice, fennel seeds, grated coconut, black pepper, ginger powder
#
#                name            state      region
# 0        balu shahi      west bengal        east
# 1            boondi        rajasthan        west
# 2    gajar ka halwa           punjab       north
# 3            ghevar        rajasthan        west
# 4       gulab jamun      west bengal        east
# ..              ...              ...         ...
# 250       til pitha            assam  north east
# 251         bebinca              goa        west
# 252          shufta  jammu & kashmir       north
# 253       mawa bati   madhya pradesh     central
# 254          pinaca              goa        west
#
# [255 rows x 4 columns]

# %% [markdown]
# #### Assessing -1 values in data set
# There are 5 different columns that possess values that do not make sense.
# Aside from the possibility that the data is merely missing I have some ideas as to why those values are like that.
# * For `prep_time` and `cook_time`, maybe this is indicitive of things that take very little time to cook, but I doubt this.
# * For `state` and `region` I think that it's possible that these dishes may be common in a wider area of India and don't have
# as much of a home as others.
# * As for `flavor_profile`, maybe the flavor for these dishes is more complicated than spicy, sweet, bitter and sour, but I doubt this.

# %%
df.map(lambda x: x == -1 or x == '-1').sum()
# Out:
# name               0
# ingredients        0
# diet               0
# prep_time         30
# cook_time         28
# flavor_profile    29
# course             0
# state             24
# region            13
# dtype: int64

# %% [markdown]
# #### Looking at categorical data
# Below I want to be able to see how many of each value is in most of the columns.
# By doing so I will have a much better idea for what kind of categories lie within the data,
# which will give me more ideas on what I can do with my imaginary restaurant menu.
# I did not include certain columns such as 'name' and 'ingredients' as they are far too unique.
# I also did not include 'prep_time' and 'cook_time' as they are better represented with something like a bar chart.
#
# #### Key points from the categorical data
# * Only 29 `non-vegetarian` options, as someone who is sensitive to plants I find this troubling, for my stomach.
# * I live in Medellín, Colombia, and the people here do not eat spicy food, it is not easy to find peppers here, but that doesn't really matter, because you can always take the spice out. Which directly relates to this project in terms of the demographics of the people that would be eating this food.
# * Mostly main courses. Only 2 `starters`, I will probably combine this with snack. Snack and starter are conceptually similar so it makes sense to combine them, especially considering there are only 2 `starters`, and having a category that small doesn't make much sense.
# * There are many regions, many of them only have a few dishes. But some of them have many. `-1` in this category makes up 24 dishes.
# * The western area of Indian seems to have the most dishes. `-1` in this category makes up 13 dishes.

# %%
for col in df.columns:
    if col not in ['prep_time', 'ingredients', 'cook_time', 'name']:
        print(df[col].value_counts(), '\n\n')
# Out:
# diet
# vegetarian        226
# non vegetarian     29
# Name: count, dtype: int64
#
#
# flavor_profile
# spicy     133
# sweet      88
# -1         29
# bitter      4
# sour        1
# Name: count, dtype: int64
#
#
# course
# main course    129
# dessert         85
# snack           39
# starter          2
# Name: count, dtype: int64
#
#
# state
# gujarat            35
# punjab             32
# maharashtra        30
# west bengal        24
# -1                 24
# assam              21
# tamil nadu         20
# andhra pradesh     10
# uttar pradesh       9
# kerala              8
# odisha              7
# karnataka           6
# rajasthan           6
# telangana           5
# bihar               3
# goa                 3
# manipur             2
# jammu & kashmir     2
# madhya pradesh      2
# uttarakhand         1
# tripura             1
# nagaland            1
# nct of delhi        1
# chhattisgarh        1
# haryana             1
# Name: count, dtype: int64
#
#
# region
# west          74
# south         59
# north         49
# east          31
# north east    25
# -1            13
# central        3
# nan            1
# Name: count, dtype: int64

# %% [markdown]
# ## `-1` data
# Now I would like to take a closer look at the `-1` data.
#
# #### Flavor profile `-1` values
# It looks like many of the items contain rice, or flour, which could mean that many of these items are
# base foods, which is something that kind of serves as a foundation for a meal. Like rice dishes and bread.
# I looked up online all the dishes here, and yes they are pretty much entirely rice and bread dishes, they all look wonderful.
#
# I did some research online and found more appropriate categories for everything that is `-1`.

# %%
df[df['flavor_profile'] == '-1']
# Out:
#                name  \
# 78          chapati
# 104            naan
# 116           rongi
# 131           kanji
# 145         pachadi
# 146       paniyaram
# 150   paruppu sadam
# 153      puli sadam
# 155           puttu
# 157         sandige
# 158           sevai
# 159    thayir sadam
# 160         theeyal
# 171          bhakri
# 176      copra paak
# 179       dahi vada
# 180        dalithoy
# 189          kansar
# 216      farsi puri
# 222            khar
# 224           luchi
# 227  bengena pitika
# 228     bilahi maas
# 229      black rice
# 231      brown rice
# 236   chingri bhape
# 244         pakhala
# 245      pani pitha
# 248        red rice
#
#                                                                           ingredients  \
# 78                         whole wheat flour, olive oil, hot water, all purpose flour
# 104                                          whole wheat flour, honey, butter, garlic
# 116                  garam masala powder, tomato, kasuri methi, cinnamon, mustard oil
# 131                                    carrot, yellow mustard, red chilli, black salt
# 145                          coconut oil, cucumber, curd, curry leaves, mustard seeds
# 146                           yogurt, ginger, curry leaves, baking soda, green chilli
# 150                      arhar dal, sambar powder, tomato, curry leaves, fennel seeds
# 153                              urad dal, lemon, tamarind, cooked rice, curry leaves
# 155                                           brown rice flour, sugar, grated coconut
# 157                                thin rice flakes, black sesame seeds, curry leaves
# 158                                                    sevai, parboiled rice, steamer
# 159                   urad dal, curd, sesame oil, ginger, curry leaves, mustard seeds
# 160                            coconut, whole red beans, masala, sesame oil, tamarind
# 171                                                         jowar flour, sesame seeds
# 176  condensed milk, nestle cream, coconut ice, red food coloring, desiccated coconut
# 179                              urad dal, bhuna chana, garam masala, dates, tamarind
# 180                   arhar dal, coconut oil, curry leaves, mustard seeds, red chilli
# 189                                                wheat flour, cashews, rapeseed oil
# 216                        semolina, clarified butter, oil, white flour, black pepper
# 222         raw papaya, panch phoran masala, nigella seeds, mustard oil, fennel seeds
# 224                                                              maida, vegetable oil
# 227                                    brinjal, onions, salt, sesame seeds, coriander
# 228                           potatoes, garam masala, tomatoes, mustard oil, bay leaf
# 229         forbidden black rice, chicken, olive oil, slivered almonds, garlic powder
# 231                                                  brown rice, soy sauce, olive oil
# 236                                  coconut, prawns, curd, mustard seed, green chili
# 244                                       curd, cooked rice, curry leaves, dry chilli
# 245                          tea leaves, white sesame seeds, dry coconut, soaked rice
# 248                              red pepper, red onion, butter, watercress, olive oil
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 78       vegetarian         10         10             -1  main course
# 104      vegetarian         60         30             -1  main course
# 116      vegetarian         10         30             -1  main course
# 131      vegetarian         10         45             -1        snack
# 145      vegetarian         10         25             -1  main course
# 146      vegetarian         10         20             -1  main course
# 150      vegetarian         10         20             -1  main course
# 153      vegetarian         10         20             -1  main course
# 155      vegetarian        495         40             -1  main course
# 157      vegetarian        120         60             -1  main course
# 158      vegetarian        120         30             -1  main course
# 159      vegetarian         10         20             -1  main course
# 160      vegetarian         15         20             -1  main course
# 171      vegetarian         20         25             -1  main course
# 176      vegetarian         20         30             -1  main course
# 179      vegetarian         30         30             -1        snack
# 180      vegetarian          5         20             -1  main course
# 189      vegetarian         10         40             -1  main course
# 216      vegetarian         -1         -1             -1        snack
# 222      vegetarian         10         20             -1  main course
# 224      vegetarian         20         30             -1  main course
# 227      vegetarian         -1         -1             -1  main course
# 228  non vegetarian         10         20             -1  main course
# 229  non vegetarian         -1         -1             -1  main course
# 231      vegetarian         15         25             -1  main course
# 236  non vegetarian         15         30             -1  main course
# 244      vegetarian         -1         -1             -1  main course
# 245      vegetarian         10         20             -1  main course
# 248      vegetarian         -1         -1             -1  main course
#
#            state      region
# 78   maharashtra        west
# 104       punjab       north
# 116       punjab       north
# 131       kerala       south
# 145           -1       south
# 146   tamil nadu       south
# 150   tamil nadu       south
# 153   tamil nadu       south
# 155       kerala       south
# 157    karnataka       south
# 158           -1       south
# 159   tamil nadu       south
# 160       kerala       south
# 171  maharashtra        west
# 176      gujarat        west
# 179  maharashtra        west
# 180  maharashtra        west
# 189      gujarat        west
# 216      gujarat        west
# 222        assam  north east
# 224  west bengal        east
# 227        assam  north east
# 228        assam  north east
# 229      manipur  north east
# 231           -1          -1
# 236  west bengal        east
# 244       odisha        east
# 245        assam  north east
# 248           -1          -1

# %%
flavor_sub1 = df[df['flavor_profile'] == '-1']['ingredients'].map(lambda x: str(x).split(', '))
flavor_sub1
# Out:
# 78                           [whole wheat flour, olive oil, hot water, all purpose flour]
# 104                                            [whole wheat flour, honey, butter, garlic]
# 116                    [garam masala powder, tomato, kasuri methi, cinnamon, mustard oil]
# 131                                      [carrot, yellow mustard, red chilli, black salt]
# 145                            [coconut oil, cucumber, curd, curry leaves, mustard seeds]
# 146                             [yogurt, ginger, curry leaves, baking soda, green chilli]
# 150                        [arhar dal, sambar powder, tomato, curry leaves, fennel seeds]
# 153                                [urad dal, lemon, tamarind, cooked rice, curry leaves]
# 155                                             [brown rice flour, sugar, grated coconut]
# 157                                  [thin rice flakes, black sesame seeds, curry leaves]
# 158                                                      [sevai, parboiled rice, steamer]
# 159                     [urad dal, curd, sesame oil, ginger, curry leaves, mustard seeds]
# 160                              [coconut, whole red beans, masala, sesame oil, tamarind]
# 171                                                           [jowar flour, sesame seeds]
# 176    [condensed milk, nestle cream, coconut ice, red food coloring, desiccated coconut]
# 179                                [urad dal, bhuna chana, garam masala, dates, tamarind]
# 180                     [arhar dal, coconut oil, curry leaves, mustard seeds, red chilli]
# 189                                                  [wheat flour, cashews, rapeseed oil]
# 216                          [semolina, clarified butter, oil, white flour, black pepper]
# 222           [raw papaya, panch phoran masala, nigella seeds, mustard oil, fennel seeds]
# 224                                                                [maida, vegetable oil]
# 227                                      [brinjal, onions, salt, sesame seeds, coriander]
# 228                             [potatoes, garam masala, tomatoes, mustard oil, bay leaf]
# 229           [forbidden black rice, chicken, olive oil, slivered almonds, garlic powder]
# 231                                                    [brown rice, soy sauce, olive oil]
# 236                                    [coconut, prawns, curd, mustard seed, green chili]
# 244                                         [curd, cooked rice, curry leaves, dry chilli]
# 245                            [tea leaves, white sesame seeds, dry coconut, soaked rice]
# 248                                [red pepper, red onion, butter, watercress, olive oil]
# Name: ingredients, dtype: object

# %%
df[df['flavor_profile'] == '-1']['name']
# Out:
# 78            chapati
# 104              naan
# 116             rongi
# 131             kanji
# 145           pachadi
# 146         paniyaram
# 150     paruppu sadam
# 153        puli sadam
# 155             puttu
# 157           sandige
# 158             sevai
# 159      thayir sadam
# 160           theeyal
# 171            bhakri
# 176        copra paak
# 179         dahi vada
# 180          dalithoy
# 189            kansar
# 216        farsi puri
# 222              khar
# 224             luchi
# 227    bengena pitika
# 228       bilahi maas
# 229        black rice
# 231        brown rice
# 236     chingri bhape
# 244           pakhala
# 245        pani pitha
# 248          red rice
# Name: name, dtype: object

# %%
sweet_dishes = ['copra paak', 'kansar', 'dahi vada', 'puttu']
spicy_dishes = ['rongi', 'theeyal', 'khar', 'bengena pitika', 'bilahi maas', 'chingri bhape', 'paniyaram']
sour_dishes = ['kanji', 'puli sadam', 'pachadi', 'pakhala']
others = ['red rice', 'pani pitha', 'pakhala', 'brown rice', 'black rice', 'luchi', 'farsi puri', 'dalithoy', 'dahi vada', 'bhakri', 'thayir sadam', 'sevai', 'sandige', 'paruppu sadam', 'naan', 'chapati']

# Updating the 'flavor' column based on the dish names
df.loc[df['name'].isin(sweet_dishes), 'flavor_profile'] = 'sweet'
df.loc[df['name'].isin(spicy_dishes), 'flavor_profile'] = 'spicy'
df.loc[df['name'].isin(others), 'flavor_profile'] = 'neutral/other'
df.loc[df['name'].isin(sour_dishes), 'flavor_profile'] = 'sour'

# %%
'''
And now all the flavor profile columns are all sorted out now to continue on to region.
'''

df['flavor_profile'].value_counts()
# Out:
# flavor_profile
# spicy            140
# sweet             91
# neutral/other     15
# sour               5
# bitter             4
# Name: count, dtype: int64

# %% [markdown]
# ### Region `-1` values

# %%
df[df['region'] == '-1']
# Out:
#                name  \
# 7        kaju katli
# 9             kheer
# 10            laddu
# 12        nankhatai
# 94          khichdi
# 96    kulfi falooda
# 98   lauki ki subji
# 109       pani puri
# 111           papad
# 117          samosa
# 164            upma
# 231      brown rice
# 248        red rice
#
#                                                              ingredients  \
# 7                                         cashews, ghee, cardamom, sugar
# 9                                        milk, rice, sugar, dried fruits
# 10                                               gram flour, ghee, sugar
# 12   refined flour, besan, ghee, powdered sugar, yoghurt, green cardamom
# 94                    moong dal, green peas, ginger, tomato, green chili
# 96                   rose syrup, falooda sev, mixed nuts, saffron, sugar
# 98       bottle gourd, coconut oil, garam masala, ginger, green chillies
# 109                        kala chana, mashed potato, boondi, sev, lemon
# 111                         urad dal, sev, lemon juice, chopped tomatoes
# 117                    potatoes, green peas, garam masala, ginger, dough
# 164                     chana dal, urad dal, ginger, curry leaves, sugar
# 231                                     brown rice, soy sauce, olive oil
# 248                 red pepper, red onion, butter, watercress, olive oil
#
#            diet  prep_time  cook_time flavor_profile       course state region
# 7    vegetarian         10         20          sweet      dessert    -1     -1
# 9    vegetarian         10         40          sweet      dessert    -1     -1
# 10   vegetarian         10         40          sweet      dessert    -1     -1
# 12   vegetarian         20         30          sweet      dessert    -1     -1
# 94   vegetarian         40         20          spicy  main course    -1     -1
# 96   vegetarian         45         25          sweet      dessert    -1     -1
# 98   vegetarian         10         20          spicy  main course    -1     -1
# 109  vegetarian         15          2          spicy        snack    -1     -1
# 111  vegetarian          5          5          spicy        snack    -1     -1
# 117  vegetarian         30         30          spicy        snack    -1     -1
# 164  vegetarian         10         20          spicy        snack    -1     -1
# 231  vegetarian         15         25  neutral/other  main course    -1     -1
# 248  vegetarian         -1         -1  neutral/other  main course    -1     -1

# %% [markdown]
# It seems that many of the foods listed seem to be from different areas of the world, or from a wide range of places in India.
# I researched as many foods as I could but there were not many that had origin data, for region and state of India.
# I used google search, mostly wikipedia to find the missing data for these foods.

# %%
region_state_data = {
    'kaju katli': {
        'region': 'north',
        'state': 'deccan'
    },
    'kheer': {
        'region': 'south'
    },
    'nankhatai': {
        'region': 'north',
        'state': 'gujarat'
    }
}

df = df.apply(lambda row: row.update(region_state_data.get(row['name'], {})) or row, axis = 1)

# %%
df[df['name'].isin(['kaju katli', 'kheer', 'nankhatai'])]
# Out:
#           name  \
# 7   kaju katli
# 9        kheer
# 12   nankhatai
#
#                                                             ingredients  \
# 7                                        cashews, ghee, cardamom, sugar
# 9                                       milk, rice, sugar, dried fruits
# 12  refined flour, besan, ghee, powdered sugar, yoghurt, green cardamom
#
#           diet  prep_time  cook_time flavor_profile   course    state region
# 7   vegetarian         10         20          sweet  dessert   deccan  north
# 9   vegetarian         10         40          sweet  dessert       -1  south
# 12  vegetarian         20         30          sweet  dessert  gujarat  north

# %% [markdown]
# #### State's `-1` values
# For the state values that are equal to -1 I went ahead and did the same thing as before looking everything up on wikipedia.
# Only to find that most dishes don't seem to have a single origin that I can find.

# %%
df[df['state'] == '-1']
# Out:
#                name  \
# 9             kheer
# 10            laddu
# 94          khichdi
# 96    kulfi falooda
# 98   lauki ki subji
# 109       pani puri
# 111           papad
# 115    rajma chaval
# 117          samosa
# 128            dosa
# 130            idli
# 144     masala dosa
# 145         pachadi
# 149         payasam
# 154           rasam
# 156          sambar
# 158           sevai
# 161         uttapam
# 162            vada
# 164            upma
# 231      brown rice
# 248        red rice
#
#                                                             ingredients  \
# 9                                       milk, rice, sugar, dried fruits
# 10                                              gram flour, ghee, sugar
# 94                   moong dal, green peas, ginger, tomato, green chili
# 96                  rose syrup, falooda sev, mixed nuts, saffron, sugar
# 98      bottle gourd, coconut oil, garam masala, ginger, green chillies
# 109                       kala chana, mashed potato, boondi, sev, lemon
# 111                        urad dal, sev, lemon juice, chopped tomatoes
# 115  red kidney beans, garam masala powder, ginger, tomato, mustard oil
# 117                   potatoes, green peas, garam masala, ginger, dough
# 128          chana dal, urad dal, whole urad dal, blend rice, rock salt
# 130          split urad dal, urad dal, idli rice, thick poha, rock salt
# 144                chana dal, urad dal, potatoes, idli rice, thick poha
# 145            coconut oil, cucumber, curd, curry leaves, mustard seeds
# 149                             rice, cashew nuts, milk, raisins, sugar
# 154              tomato, curry leaves, garlic, mustard seeds, hot water
# 156          pigeon peas, eggplant, drumsticks, sambar powder, tamarind
# 158                                      sevai, parboiled rice, steamer
# 161                     chana dal, urad dal, thick poha, tomato, butter
# 162         urad dal, ginger, curry leaves, green chilies, black pepper
# 164                    chana dal, urad dal, ginger, curry leaves, sugar
# 231                                    brown rice, soy sauce, olive oil
# 248                red pepper, red onion, butter, watercress, olive oil
#
#            diet  prep_time  cook_time flavor_profile       course state region
# 9    vegetarian         10         40          sweet      dessert    -1  south
# 10   vegetarian         10         40          sweet      dessert    -1     -1
# 94   vegetarian         40         20          spicy  main course    -1     -1
# 96   vegetarian         45         25          sweet      dessert    -1     -1
# 98   vegetarian         10         20          spicy  main course    -1     -1
# 109  vegetarian         15          2          spicy        snack    -1     -1
# 111  vegetarian          5          5          spicy        snack    -1     -1
# 115  vegetarian         15         90          spicy  main course    -1  north
# 117  vegetarian         30         30          spicy        snack    -1     -1
# 128  vegetarian        360         90          spicy        snack    -1  south
# 130  vegetarian        360         90          spicy        snack    -1  south
# 144  vegetarian        360         90          spicy        snack    -1  south
# 145  vegetarian         10         25           sour  main course    -1  south
# 149  vegetarian         15         30          sweet      dessert    -1  south
# 154  vegetarian         10         35          spicy  main course    -1  south
# 156  vegetarian         20         45          spicy  main course    -1  south
# 158  vegetarian        120         30  neutral/other  main course    -1  south
# 161  vegetarian         10         20          spicy        snack    -1  south
# 162  vegetarian         15         20          spicy        snack    -1  south
# 164  vegetarian         10         20          spicy        snack    -1     -1
# 231  vegetarian         15         25  neutral/other  main course    -1     -1
# 248  vegetarian         -1         -1  neutral/other  main course    -1     -1

# %%
state_update_values = {
    'idli': {
        'region': 'south'
    },
    'masala dosa': {
        'region': 'south'
    },
    'pachadi': {
        'region': 'south'
    },
    'rasam': {
        'region': 'south'
    },
    'sambar': {
        'region': 'south'
    },
    'uttappam': {
        'region': 'south'
    }
}

df = df.apply(lambda row: row.update(state_update_values.get(row['name'], {})) or row, axis = 1)
df[df['name'].isin([k for k, v in state_update_values.items()])]
# Out:
#             name                                                 ingredients  \
# 130         idli  split urad dal, urad dal, idli rice, thick poha, rock salt
# 144  masala dosa        chana dal, urad dal, potatoes, idli rice, thick poha
# 145      pachadi    coconut oil, cucumber, curd, curry leaves, mustard seeds
# 154        rasam      tomato, curry leaves, garlic, mustard seeds, hot water
# 156       sambar  pigeon peas, eggplant, drumsticks, sambar powder, tamarind
#
#            diet  prep_time  cook_time flavor_profile       course state region
# 130  vegetarian        360         90          spicy        snack    -1  south
# 144  vegetarian        360         90          spicy        snack    -1  south
# 145  vegetarian         10         25           sour  main course    -1  south
# 154  vegetarian         10         35          spicy  main course    -1  south
# 156  vegetarian         20         45          spicy  main course    -1  south

# %% [markdown]
# #### Cook time & prep time `-1` values
# To save on time I am just going to have ChatGPT just make me a dictionary of approxiate cook and prep times.

# %%
df[df.eq(-1).any(axis = 1)]
# Out:
#                name  \
# 19      sohan papdi
# 21    chhena kheeri
# 65      pork bharta
# 132  kaara kozhambu
# 134  keerai masiyal
# 148      paravannam
# 152         poriyal
# 167     kolim jawla
# 172      bombil fry
# 185        ghooghra
# 187        halvasan
# 213      mag dhokli
# 216      farsi puri
# 220      cheera doi
# 223     kumol sawul
# 227  bengena pitika
# 229      black rice
# 230      bora sawul
# 234      hando guri
# 237        kabiraji
# 238         khorisa
# 239  koldil chicken
# 240       konir dom
# 241     koldil duck
# 242      masor koni
# 244         pakhala
# 246          payokh
# 248        red rice
# 252          shufta
# 254          pinaca
#
#                                                                        ingredients  \
# 19                                         gram flour, ghee, sugar, milk, cardamom
# 21                                                             chhena, sugar, milk
# 65                                boiled pork, onions, chillies, ginger and garlic
# 132                   sesame oil, drumstick, tamarind paste, sambar powder, tomato
# 134                          urad dal, curry leaves, sugar, mustard seeds, spinach
# 148                                                       raw rice,  jaggery, milk
# 152                                   chana dal, urad dal, beans, coconut, mustard
# 167                              baingan, fish, coconut oil, fresh coconut, ginger
# 172            bombay duck, malvani masala, rice flour, bombay rava, green chilies
# 185                                        dry fruits, semolina, all purpose flour
# 187                     whole wheat rava, chia seed, lemon, edible gum, litre milk
# 213                                  moong beans, jaggery, red chillies, oil, salt
# 216                     semolina, clarified butter, oil, white flour, black pepper
# 220                                                              rice, mango, curd
# 223                                                   rice, eggs, carrot, beetroot
# 227                                 brinjal, onions, salt, sesame seeds, coriander
# 229      forbidden black rice, chicken, olive oil, slivered almonds, garlic powder
# 230  biryani masala, mixed vegetables, yellow moong daal, whole red, mustard seeds
# 234                                                               jaggery, raisins
# 237                                        fish fillet, besan, lemon, mint, ginger
# 238                     fermented bamboo shoot, potato, ginger, green, mustard oil
# 239                  banana flower, chicken, green chili, mustard oil, lemon juice
# 240                          aloo, tomatoes, mustard oil, bay leaf, cinnamon stick
# 241               rice flour, mutton, banana, gram flour, olive oil, baking powder
# 242                       fish roe, pumpkin flowers, mustard oil, turmeric, tomato
# 244                                    curd, cooked rice, curry leaves, dry chilli
# 246               basmati rice, rose water, sugar, clarified butter, cardamom pods
# 248                           red pepper, red onion, butter, watercress, olive oil
# 252                 cottage cheese, dry dates, dried rose petals, pistachio, badam
# 254          brown rice, fennel seeds, grated coconut, black pepper, ginger powder
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 19       vegetarian         -1         60          sweet      dessert
# 21       vegetarian         -1         60          sweet      dessert
# 65   non vegetarian         -1         -1          spicy  main course
# 132      vegetarian         -1         -1          spicy  main course
# 134      vegetarian         -1         -1          spicy  main course
# 148      vegetarian         -1         -1          spicy  main course
# 152      vegetarian         -1         -1          spicy  main course
# 167  non vegetarian         -1         -1          spicy  main course
# 172  non vegetarian         -1         -1          spicy  main course
# 185      vegetarian         -1         -1          spicy        snack
# 187      vegetarian         -1         -1          sweet      dessert
# 213      vegetarian         -1         -1          spicy        snack
# 216      vegetarian         -1         -1  neutral/other        snack
# 220      vegetarian         -1         -1          sweet      dessert
# 223  non vegetarian         -1         -1          spicy  main course
# 227      vegetarian         -1         -1          spicy  main course
# 229  non vegetarian         -1         -1  neutral/other  main course
# 230      vegetarian         -1         -1          spicy  main course
# 234      vegetarian         -1         -1          sweet      dessert
# 237  non vegetarian         -1         -1          spicy  main course
# 238      vegetarian         -1         -1          spicy  main course
# 239  non vegetarian         -1         -1          spicy  main course
# 240  non vegetarian         -1         -1          spicy  main course
# 241  non vegetarian         -1         -1          spicy  main course
# 242  non vegetarian         -1         -1          spicy  main course
# 244      vegetarian         -1         -1           sour  main course
# 246      vegetarian         -1         -1          sweet      dessert
# 248      vegetarian         -1         -1  neutral/other  main course
# 252      vegetarian         -1         -1          sweet      dessert
# 254      vegetarian         -1         -1          sweet      dessert
#
#                state      region
# 19       maharashtra        west
# 21            odisha        east
# 65           tripura  north east
# 132       tamil nadu       south
# 134       tamil nadu       south
# 148           kerala       south
# 152       tamil nadu       south
# 167      maharashtra        west
# 172      maharashtra        west
# 185          gujarat        west
# 187          gujarat        west
# 213          gujarat        west
# 216          gujarat        west
# 220      west bengal        east
# 223            assam  north east
# 227            assam  north east
# 229          manipur  north east
# 230            assam  north east
# 234            assam  north east
# 237      west bengal        east
# 238            assam  north east
# 239            assam  north east
# 240            assam  north east
# 241            assam  north east
# 242            assam  north east
# 244           odisha        east
# 246            assam  north east
# 248               -1          -1
# 252  jammu & kashmir       north
# 254              goa        west

# %%
dish_cook_times = {
    'sohan papdi': 60,  
    'chhena kheeri': 45,  
    'pork bharta': 90,  
    'kaara kozhambu': 30,  
    'keerai masiyal': 25,  
    'paravannam': 35,  
    'poriyal': 20,  
    'kolim jawla': 25,  
    'bombil fry': 15,  
    'ghooghra': 30,  
    'halvasan': 45,  
    'mag dhokli': 60,  
    'farsi puri': 20,  
    'cheera doi': 240,  
    'kumol sawul': 20,  
    'bengena pitika': 30,  
    'black rice': 50,  
    'bora sawul': 25,  
    'hando guri': 60,  
    'kabiraji': 30,  
    'khorisa': 10,  
    'koldil chicken': 60,  
    'konir dom': 45,  
    'koldil duck': 120,  
    'masor koni': 20,  
    'pakhala': 10,  
    'payokh': 45,  
    'red rice': 50,  
    'shufta': 30,  
    'pinaca': 40  
}
dish_prep_times = {
    'sohan papdi': 30,
    'chhena kheeri': 15,
    'pork bharta': 20,
    'kaara kozhambu': 20,
    'keerai masiyal': 15,
    'paravannam': 15,
    'poriyal': 10,
    'kolim jawla': 15,
    'bombil fry': 20,
    'ghooghra': 45,
    'halvasan': 30,
    'mag dhokli': 30,
    'farsi puri': 40,
    'cheera doi': 15,
    'kumol sawul': 5,
    'bengena pitika': 10,
    'black rice': 10,
    'bora sawul': 10,
    'hando guri': 10,
    'kabiraji': 30,
    'khorisa': 10,
    'koldil chicken': 20,
    'konir dom': 20,
    'koldil duck': 20,
    'masor koni': 10,
    'pakhala': 10,
    'payokh': 15,
    'red rice': 10,
    'shufta': 30,
    'pinaca': 15
}

prep_cook_times = {}
for food in dish_prep_times:
    prep_cook_times[food] = {
        'prep_time': dish_prep_times[food],
        'cook_time': dish_cook_times.get(food, None)
    }

for food, times in prep_cook_times.items():
    mask = df['name'] == food
    df.loc[mask, 'prep_time'] = times['prep_time']
    df.loc[mask, 'cook_time'] = times['cook_time']

df[df['name'].isin([k for k, v in prep_cook_times.items()])]
# Out:
#                name  \
# 19      sohan papdi
# 21    chhena kheeri
# 65      pork bharta
# 132  kaara kozhambu
# 134  keerai masiyal
# 148      paravannam
# 152         poriyal
# 167     kolim jawla
# 172      bombil fry
# 185        ghooghra
# 187        halvasan
# 213      mag dhokli
# 216      farsi puri
# 220      cheera doi
# 223     kumol sawul
# 227  bengena pitika
# 229      black rice
# 230      bora sawul
# 234      hando guri
# 237        kabiraji
# 238         khorisa
# 239  koldil chicken
# 240       konir dom
# 241     koldil duck
# 242      masor koni
# 244         pakhala
# 246          payokh
# 248        red rice
# 252          shufta
# 254          pinaca
#
#                                                                        ingredients  \
# 19                                         gram flour, ghee, sugar, milk, cardamom
# 21                                                             chhena, sugar, milk
# 65                                boiled pork, onions, chillies, ginger and garlic
# 132                   sesame oil, drumstick, tamarind paste, sambar powder, tomato
# 134                          urad dal, curry leaves, sugar, mustard seeds, spinach
# 148                                                       raw rice,  jaggery, milk
# 152                                   chana dal, urad dal, beans, coconut, mustard
# 167                              baingan, fish, coconut oil, fresh coconut, ginger
# 172            bombay duck, malvani masala, rice flour, bombay rava, green chilies
# 185                                        dry fruits, semolina, all purpose flour
# 187                     whole wheat rava, chia seed, lemon, edible gum, litre milk
# 213                                  moong beans, jaggery, red chillies, oil, salt
# 216                     semolina, clarified butter, oil, white flour, black pepper
# 220                                                              rice, mango, curd
# 223                                                   rice, eggs, carrot, beetroot
# 227                                 brinjal, onions, salt, sesame seeds, coriander
# 229      forbidden black rice, chicken, olive oil, slivered almonds, garlic powder
# 230  biryani masala, mixed vegetables, yellow moong daal, whole red, mustard seeds
# 234                                                               jaggery, raisins
# 237                                        fish fillet, besan, lemon, mint, ginger
# 238                     fermented bamboo shoot, potato, ginger, green, mustard oil
# 239                  banana flower, chicken, green chili, mustard oil, lemon juice
# 240                          aloo, tomatoes, mustard oil, bay leaf, cinnamon stick
# 241               rice flour, mutton, banana, gram flour, olive oil, baking powder
# 242                       fish roe, pumpkin flowers, mustard oil, turmeric, tomato
# 244                                    curd, cooked rice, curry leaves, dry chilli
# 246               basmati rice, rose water, sugar, clarified butter, cardamom pods
# 248                           red pepper, red onion, butter, watercress, olive oil
# 252                 cottage cheese, dry dates, dried rose petals, pistachio, badam
# 254          brown rice, fennel seeds, grated coconut, black pepper, ginger powder
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 19       vegetarian         30         60          sweet      dessert
# 21       vegetarian         15         45          sweet      dessert
# 65   non vegetarian         20         90          spicy  main course
# 132      vegetarian         20         30          spicy  main course
# 134      vegetarian         15         25          spicy  main course
# 148      vegetarian         15         35          spicy  main course
# 152      vegetarian         10         20          spicy  main course
# 167  non vegetarian         15         25          spicy  main course
# 172  non vegetarian         20         15          spicy  main course
# 185      vegetarian         45         30          spicy        snack
# 187      vegetarian         30         45          sweet      dessert
# 213      vegetarian         30         60          spicy        snack
# 216      vegetarian         40         20  neutral/other        snack
# 220      vegetarian         15        240          sweet      dessert
# 223  non vegetarian          5         20          spicy  main course
# 227      vegetarian         10         30          spicy  main course
# 229  non vegetarian         10         50  neutral/other  main course
# 230      vegetarian         10         25          spicy  main course
# 234      vegetarian         10         60          sweet      dessert
# 237  non vegetarian         30         30          spicy  main course
# 238      vegetarian         10         10          spicy  main course
# 239  non vegetarian         20         60          spicy  main course
# 240  non vegetarian         20         45          spicy  main course
# 241  non vegetarian         20        120          spicy  main course
# 242  non vegetarian         10         20          spicy  main course
# 244      vegetarian         10         10           sour  main course
# 246      vegetarian         15         45          sweet      dessert
# 248      vegetarian         10         50  neutral/other  main course
# 252      vegetarian         30         30          sweet      dessert
# 254      vegetarian         15         40          sweet      dessert
#
#                state      region
# 19       maharashtra        west
# 21            odisha        east
# 65           tripura  north east
# 132       tamil nadu       south
# 134       tamil nadu       south
# 148           kerala       south
# 152       tamil nadu       south
# 167      maharashtra        west
# 172      maharashtra        west
# 185          gujarat        west
# 187          gujarat        west
# 213          gujarat        west
# 216          gujarat        west
# 220      west bengal        east
# 223            assam  north east
# 227            assam  north east
# 229          manipur  north east
# 230            assam  north east
# 234            assam  north east
# 237      west bengal        east
# 238            assam  north east
# 239            assam  north east
# 240            assam  north east
# 241            assam  north east
# 242            assam  north east
# 244           odisha        east
# 246            assam  north east
# 248               -1          -1
# 252  jammu & kashmir       north
# 254              goa        west

# %%
df.to_csv('../data/processed_indian_food.csv', index = False)
# Out:
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
# ...
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "c:\Users\OMEN\anaconda3\Lib\asyncio\selector_events.py", line 119, in _read_from_self
#     data = self._ssock.recv(4096)
#            ^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [WinError 10054] Se ha forzado la interrupción de una conexión existente por el host remoto

# %% [markdown]
# ### Finishing up
# Looking at the data now I think that I am satisfied with what I have. there still are some -1 values in there, but I am fine with that.
# I searched online for information pertaining to those particular data points and found that there was no answer or that there was more than one answer.
# So now it is time to move onto the data analysis portion of the project.
